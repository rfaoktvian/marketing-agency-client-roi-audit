# %% [markdown]
# ## DATA CLEANING & PREPROCESSING

# %% [markdown]
# ### IMPORT LIBRARY

# %%
import warnings
warnings.filterwarnings("ignore")

from pathlib import Path

import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### LOAD DATA

# %%
DATA_DIR = Path("../data/raw")

def load_table(filename: str) -> pd.DataFrame:
    df = pd.read_csv(DATA_DIR / filename)
    print(f"{filename}: {df.shape[0]} rows, {df.shape[1]} cols")
    return df

clients     = load_table("clients.csv")
campaigns   = load_table("campaigns.csv")
ad_spend    = load_table("ad_spend.csv")
leads       = load_table("leads.csv")
conversions = load_table("conversions.csv")
# Out:
# clients.csv: 50 rows, 8 cols
# campaigns.csv: 500 rows, 10 cols
# ad_spend.csv: 3000 rows, 10 cols
# leads.csv: 2500 rows, 8 cols
# conversions.csv: 400 rows, 7 cols
